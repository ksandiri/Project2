# %% [markdown]
# Pandas & Data Cleaning Demo

# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/background survey.csv')

# %%
df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2026/01/11 7:00:22 PM EST       First Last 1
# 1   2026/01/11 7:52:56 PM EST            First 2
# 2   2026/01/11 8:29:18 PM EST       First Last 3
# 3  2026/01/12 12:45:08 AM EST       First Last 4
# 4   2026/01/12 8:43:02 AM EST       First Last 5
#
#   Did you grow up in North Carolina?  How old are you?  \
# 0                                Yes                20
# 1                                Yes                23
# 2                                 No                21
# 3                                Yes                20
# 4                                Yes                20
#
#   What level of a student are you?  How familiar are you with "data science"?  \
# 0                        Sophomore                                          3
# 1                           Junior                                          2
# 2                           Junior                                          4
# ...

# %%
df.tail()
# Out:
#                      Timestamp What is your name?  \
# 95   2026/01/13 9:23:32 PM EST      First Last 36
# 96  2026/01/13 11:24:47 PM EST      First Last 83
# 97  2026/01/14 12:06:27 AM EST      First Last 84
# 98   2026/01/14 9:22:19 AM EST      First Last 85
# 99   2026/01/14 9:24:54 AM EST           First 86
#
#    Did you grow up in North Carolina?  How old are you?  \
# 95                                 No                20
# 96                                 No                35
# 97                                Yes                23
# 98                                Yes                21
# 99                                 No                21
#
#    What level of a student are you?  \
# 95                           Junior
# 96                           Junior
# 97                           Junior
# 98                           Junior
# 99                           Junior
#
#     How familiar are you with "data science"?  \
# ...

# %%
df.shape
# Out:
# (100, 10)

# %%
df.describe()
# Out:
#        How old are you?  How familiar are you with "data science"?  \
# count        100.000000                                 100.000000
# mean          21.010000                                   3.210000
# std            3.767203                                   0.868006
# min           18.000000                                   1.000000
# 25%           19.000000                                   3.000000
# 50%           20.000000                                   3.000000
# 75%           21.000000                                   4.000000
# max           35.000000                                   5.000000
#
#        How familiar are you with "social science"  \
# count                                  100.000000
# mean                                     2.910000
# std                                      1.015983
# min                                      1.000000
# 25%                                      2.000000
# 50%                                      3.000000
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'What is your name?', 'Did you grow up in North Carolina?',
#        'How old are you?', 'What level of a student are you?',
#        'How familiar are you with "data science"?',
#        'How familiar are you with "social science"',
#        'How nervous are you for this class?',
#        'Are you excited for this class?',
#        'How do you think generative AI should be used or treated in this course? Don't be shy, we're looking for honest, insightful ideas,'],
#       dtype='object')

# %% [markdown]
# TODO: Discuss and write down: types of questions and possible cleaning we will need to do. Use your tools!

# %% [markdown]
# ### Possible questions to answer:
# - average age of students
# - general vibes/feelings of the class. where to focus the class?
# - with lower level of familiarity -> maybe slower, more hollistic approach
# - average time students submitted the form
# - general views on AI
# - how far along students are in their program of study
#
# ### Possible data cleaning:
# - if no names or identifiers - what do we do about that
# - how do we handle duplicates?
# - check data types
# - consider quotations in open ended text feautures and how to handle them
